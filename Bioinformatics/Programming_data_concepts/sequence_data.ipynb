# %%
from Bio import SeqIO
infile="CDS.fa"
for seq_record in SeqIO.parse(infile, "fasta"):
    #print(seq_record.seq)
    for i in range(0,len(seq_record),3):
        print(f'{i:5} {seq_record.seq[i:i+3]} {seq_record.seq[i:i+3].translate()}')
#print(f'{num_seqs} sequences; total len is {total_length}')
# Out:
#     0 ATG M
#     3 CTC L
#     6 GCA A
#     9 TTC F
#    12 TCC S
#    15 TCT S
#    18 GGC G
#    21 ATC I
#    24 GTT V
#    27 TCC S
#    30 ACC T
#    33 TTG L
#    36 ACG T
#    39 CCA P
#    42 TAT Y
#    45 GTC V
#    48 ACA T
#    51 AGC S
#    54 TCG S
#    57 TTC F
#    60 CAA Q
#    63 ATG M
#    66 CAT H
#    69 TCC S
#    72 TTG L
#    75 ACT T
#    78 GCA A
#    81 ACC T
#    84 ACC T
#    87 AGT S
#    90 ATC I
#    93 ATT I
#    96 TCA S
#    99 TCC S
#   102 TTG L
#   105 ATT I
#   108 GGA G
#   111 GGC G
#   114 CTC L
#   117 TTC F
#   120 AAG K
#   123 ATC I
#   126 CCC P
#   129 TAC Y
#   132 GCC A
#   135 AAA K
#   138 ATT I
#   141 CTT L
#   144 GAT D
#   147 ATT I
#   150 TGG W
#   153 GGT G
#   156 CGT R
#   159 CCA P
#   162 CAG Q
#   165 GCC A
#   168 TTC F
#   171 TTG L
#   174 ATC I
#   177 ATG M
#   180 GTC V
#   183 TCC S
#   186 TCG S
#   189 ATC I
#   192 ACT T
#   195 CTT L
#   198 GGT G
#   201 CTC L
#   204 GTG V
#   207 ATG M
#   210 ATG M
#   213 GCG A
#   216 GGT G
#   219 TGC C
#   222 AAT N
#   225 GAT D
#   228 GTC V
#   231 AAG K
#   234 ACC T
#   237 TAT Y
#   240 TGC C
#   243 GCC A
#   246 GCC A
#   249 CAA Q
#   252 GTC V
#   255 TTC F
#   258 TAC Y
#   261 TCT S
#   264 GTT V
#   267 GGG G
#   270 TAC Y
#   273 ACA T
#   276 GGC G
#   279 ATC I
#   282 GAC D
#   285 TTC F
#   288 TCC S
#   291 ATG M
#   294 ACC T
#   297 ATC I
#   300 TTC F
#   303 GTA V
#   306 GCC A
#   309 GAC D
#   312 ACG T
#   315 TCC S
#   318 AAG K
#   321 CTG L
#   324 CGA R
#   327 AAT N
#   330 CGT R
#   333 GCT A
#   336 TTT F
#   339 ATG M
#   342 CTC L
#   345 GCC A
#   348 TTC F
#   351 ACA T
#   354 GCT A
#   357 TCC S
#   360 CCG P
#   363 TAC Y
#   366 CTC L
#   369 GTC V
#   372 ACC T
#   375 ACG T
#   378 TGG W
#   381 GCT A
#   384 TAC Y
#   387 GGT G
#   390 CCG P
#   393 GCT A
#   396 GTT V
#   399 AAC N
#   402 AGC S
#   405 ATC I
#   408 CTT L
#   411 AGT S
#   414 ACT T
#   417 ATC I
#   420 GGG G
#   423 TAC Y
#   426 AGA R
#   429 TGG W
#   432 GGC G
#   435 TTT F
#   438 GGC G
#   441 ATC I
#   444 TGG W
#   447 GCG A
#   450 ATC I
#   453 GTG V
#   456 CTG L
#   459 CCG P
#   462 CTG L
#   465 ATT I
#   468 TGT C
#   471 GCA A
#   474 CCG P
#   477 CTC L
#   480 TGC C
#   483 GCA A
#   486 CTA L
#   489 TTC F
#   492 TGG W
#   495 TAC Y
#   498 AAC N
#   501 CAA Q
#   504 AGA R
#   507 AAG K
#   510 GCC A
#   513 AAC N
#   516 AAC N
#   519 TTG L
#   522 GGG G
#   525 CTC L
#   528 ATC I
#   531 CCT P
#   534 CCT P
#   537 CGA R
#   540 CCA P
#   543 AGC S
#   546 CGT R
#   549 GGA G
#   552 AAT N
#   555 GCT A
#   558 TTT F
#   561 GAA E
#   564 ACC T
#   567 TTC F
#   570 ATC I
#   573 TAC Y
#   576 TAC Y
#   579 TGC C
#   582 CGG R
#   585 GAG E
#   588 TTC F
#   591 GAT D
#   594 GTC V
#   597 ATC I
#   600 GGA G
#   603 CTG L
#   606 CTT L
#   609 ATC I
#   612 ATC I
#   615 AGC S
#   618 ACA T
#   621 GGA G
#   624 CTG L
#   627 GCG A
#   630 CTT L
#   633 TTC F
#   636 CTG L
#   639 CTG L
#   642 TCG S
#   645 TTC F
#   648 AGC S
#   651 CTG L
#   654 TAC Y
#   657 TCC S
#   660 TAC Y
#   663 CAA Q
#   666 AAG K
#   669 GAC D
#   672 GAG E
#   675 TGG W
#   678 AGA R
#   681 TCA S
#   684 CCA P
#   687 CTC L
#   690 ATC I
#   693 ATT I
#   696 TGC C
#   699 TTC F
#   702 CTC L
#   705 ATC I
#   708 TTC F
#   711 GGG G
#   714 GGC G
#   717 TTG L
#   720 CTC L
#   723 ATC I
#   726 ATT I
#   729 GCG A
#   732 TTC F
#   735 GGA G
#   738 TTG L
#   741 TAC Y
#   744 GAG E
#   747 AAA K
#   750 TAC Y
#   753 CTT L
#   756 GCA A
#   759 CCA P
#   762 GTT V
#   765 ACG T
#   768 TTC F
#   771 ATC I
#   774 CCT P
#   777 TGG W
#   780 TAT Y
#   783 TTG L
#   786 TTG L
#   789 AAG K
#   792 AAC N
#   795 CGC R
#   798 ACC T
#   801 ATC I
#   804 ATC I
#   807 TTC F
#   810 ACC T
#   813 TAT Y
#   816 ACC T
#   819 ATG M
#   822 GCA A
#   825 GCC A
#   828 AGC S
#   831 ATC I
#   834 TAC Y
#   837 GTT V
#   840 GCC A
#   843 TGG W
#   846 TAC Y
#   849 ATC I
#   852 TGG W
#   855 GAC D
#   858 AGC S
#   861 TAC Y
#   864 TTC F
#   867 TAC Y
#   870 TCG S
#   873 CTC L
#   876 AAT N
#   879 ATC I
#   882 GTC V
#   885 CTG L
#   888 TTC F
#   891 CGG R
#   894 CAA Q
#   897 TCA S
#   900 ATC I
#   903 ACG T
#   906 CAA Q
#   909 GCG A
#   912 ACG T
#   915 TAC Y
#   918 ATC I
#   921 GGC G
#   924 AAC N
#   927 ATC I
#   930 TAC Y
#   933 ACC T
#   936 ATC I
#   939 GGA G
#   942 TCC S
#   945 TGC C
#   948 TTC F
#   951 TGG W
#   954 TCA S
#   957 CTT L
#   960 GTC V
#   963 CTC L
#   966 GGC G
#   969 GTT V
#   972 TGC C
#   975 ATT I
#   978 CGC R
#   981 TTC F
#   984 AAC N
#   987 GGC G
#   990 CGC R
#   993 ATA I
#   996 AAA K
#   999 TGG W
#  1002 TAT Y
#  1005 GCG A
#  1008 CTG L
#  1011 TGC C
#  1014 TTC F
#  1017 GGA G
#  1020 GTT V
#  1023 CCA P
#  1026 CTG L
#  1029 ACG T
#  1032 ATC I
#  1035 CTC L
#  1038 GGT G
#  1041 GTT V
#  1044 GGA G
#  1047 CTG L
#  1050 ATG M
#  1053 ATC I
#  1056 CAT H
#  1059 TTC F
#  1062 CGC R
#  1065 CAA Q
#  1068 CCG P
#  1071 GGT G
#  1074 GTC V
#  1077 CAC H
#  1080 ATC I
#  1083 GGC G
#  1086 TAC Y
#  1089 ATC I
#  1092 GTC V
#  1095 ATG M
#  1098 TGC C
#  1101 CAG Q
#  1104 ATC I
#  1107 TTT F
#  1110 GTC V
#  1113 GCT A
#  1116 TTC F
#  1119 GGT G
#  1122 GGC G
#  1125 GGT G
#  1128 ACA T
#  1131 CTC L
#  1134 GTT V
#  1137 ATC I
#  1140 TGC C
#  1143 GAG E
#  1146 CAG Q
#  1149 ATA I
#  1152 ACT T
#  1155 GTC V
#  1158 ATG M
#  1161 GCG A
#  1164 GTC V
#  1167 TCC S
#  1170 ACC T
#  1173 CAT H
#  1176 CAG Q
#  1179 CAC H
#  1182 ATT I
#  1185 CCG P
#  1188 GCG A
#  1191 GTC V
#  1194 CTC L
#  1197 GCC A
#  1200 ATG M
#  1203 GAG E
#  1206 GGA G
#  1209 TTG L
#  1212 GTC V
#  1215 GCG A
#  1218 TAT Y
#  1221 GTC V
#  1224 GGC G
#  1227 AGT S
#  1230 TCA S
#  1233 ATC I
#  1236 GGA G
#  1239 CTG L
#  1242 GCA A
#  1245 ATC I
#  1248 GCC A
#  1251 GCA A
#  1254 GCC A
#  1257 ATG M
#  1260 TGG W
#  1263 ACT T
#  1266 GGT G
#  1269 ATC I
#  1272 TTT F
#  1275 CCA P
#  1278 CAG Q
#  1281 AAA K
#  1284 TTG L
#  1287 TTG L
#  1290 GAA E
#  1293 AAC N
#  1296 CTA L
#  1299 CCT P
#  1302 GCA A
#  1305 AGT S
#  1308 GCA A
#  1311 CAA Q
#  1314 TCC S
#  1317 GAC D
#  1320 TTT F
#  1323 GCC A
#  1326 AGC S
#  1329 ATC I
#  1332 TAC Y
#  1335 GGT G
#  1338 GAC D
#  1341 TTG L
#  1344 ACC T
#  1347 GTA V
#  1350 CAA Q
#  1353 GCC A
#  1356 AGT S
#  1359 TAC Y
#  1362 CCT P
#  1365 GTT V
#  1368 GGA G
#  1371 AGT S
#  1374 CCG P
#  1377 ACA T
#  1380 AGA R
#  1383 ATT I
#  1386 GCA A
#  1389 ATC I
#  1392 GAT D
#  1395 AAG K
#  1398 TCG S
#  1401 TAC Y
#  1404 GCA A
#  1407 GAG E
#  1410 ACC T
#  1413 CAA Q
#  1416 AGG R
#  1419 CTG L
#  1422 ATG M
#  1425 CTG L
#  1428 ATC I
#  1431 GCC A
#  1434 GCT A
#  1437 ACC T
#  1440 AGT S
#  1443 TTG L
#  1446 TAC Y
#  1449 ACA T
#  1452 ATC I
#  1455 ACG T
#  1458 CTG L
#  1461 GTC V
#  1464 TCA S
#  1467 ACT T
#  1470 GCC A
#  1473 TTG L
#  1476 TGG W
#  1479 AAG K
#  1482 GAT D
#  1485 ATT I
#  1488 GAT D
#  1491 GTC V
#  1494 AAG K
#  1497 AAC N
#  1500 ATG M
#  1503 ACG T
#  1506 CAG Q
#  1509 CGC R
#  1512 ACC T
#  1515 AAG K
#  1518 GGT G
#  1521 TTG L
#  1524 ATC I
#  1527 TAG *
